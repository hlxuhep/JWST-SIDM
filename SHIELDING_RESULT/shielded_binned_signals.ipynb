# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib as mpl
from pathlib import Path
import natural_units as nu
from scipy.special import erf
from scipy.integrate import quad
from scipy.interpolate import RegularGridInterpolator
from scipy.interpolate import interp1d
import re
# multi-core/thread:
import concurrent.futures

# %%
# HgCdTe form factors' parameters
N_q   = 800
N_E   = 300
dE    = 0.05 * nu.eV
dq    = 0.01 * nu.aEM * nu.mElectron
E_max = N_E * dE
q_max = N_q * dq
energy_gap = 0.234 * nu.eV
epsilon    = 3 * energy_gap
M_cell     = 301.74 * nu.AMU
Q_max      = np.floor((E_max - energy_gap + epsilon) / epsilon)
# Read form factor files
ff_hgte_grid = np.zeros((N_q,N_E))
ff_cdte_grid = np.zeros((N_q,N_E))
hgte_data_file = np.loadtxt('../data/form_factors/C.HgTe137.dat')
cdte_data_file = np.loadtxt('../data/form_factors/C.CdTe137.dat')
lin2_data_file = np.loadtxt('../data/form_factors/Lin2_HgCdTe.txt')
i=0
for Ei in range(N_E):
    for qi in range(N_q):
        ff_hgte_grid[qi, Ei] = hgte_data_file[i]
        ff_cdte_grid[qi, Ei] = cdte_data_file[i]
        i += 1

# correct by Lindhard:
ff_hgte_grid = ff_hgte_grid / lin2_data_file
ff_cdte_grid = ff_cdte_grid / lin2_data_file

# Interplot form factors
q_grid = np.linspace(dq, q_max, N_q)
E_grid = np.linspace(dE, E_max, N_E)

ff_hgte = RegularGridInterpolator((q_grid, E_grid), ff_hgte_grid)
ff_cdte = RegularGridInterpolator((q_grid, E_grid), ff_cdte_grid)
# To determine light or heavy mediator, just in case
mA = 0.0
def F_DM(q):
    return ((nu.aEM*nu.mElectron)**2 + mA**2)/(q**2 + mA**2)
def v_min(q, Ee, mDM):
    return Ee/q + q/2/mDM

def charge_yield(Ee, Q):
        if Ee < energy_gap:
            return 0
        else:
            Ee_1 = epsilon * (Q - 1) + energy_gap
            Ee_2 = epsilon * Q + energy_gap
            if Ee < Ee_1 or Ee > Ee_2:
                return 0.0
            else:
                return 1.0

# %%
# Halo DM parameters, just in case
rho_DM  = 0.3 * nu.GeV / nu.cm**3
frac_DM = 4e-3
# JWST parameters
pixel_mass = 1.2e-8 *nu.gram
exposure_time   = 3574.278 *nu.sec * 244 / 245  # since we are using (last frame - first frame)
exposure = pixel_mass * exposure_time

eta_func_path = Path('../data/DM_eta_function')
result_dir = Path('./result')
binned_signal_dir = Path('../data/binned_signal_w_shield_w_lindhard')
pattern = re.compile(r"mDM=([0-9.eE+-]+)_GeV_sigma=([0-9.eE+-]+)_cm2")

result_dir.mkdir(parents=True, exist_ok=True)
binned_signal_dir.mkdir(parents=True, exist_ok=True)
eta_func_jobs = {}
for filename in eta_func_path.glob('*.txt'):
    match = pattern.search(filename.stem)
    if match is None:
        continue
    key = (float(match.group(1)), float(match.group(2)))
    if key in eta_func_jobs:
        raise RuntimeError(f'Duplicate physical point in {eta_func_path}: {key}')
    output_stem = filename.stem[9:-11]
    eta_func_jobs[key] = (
        filename,
        result_dir / (output_stem + '.txt'),
        binned_signal_dir / ('binned_signals_' + output_stem + '.txt'),
    )

if len(eta_func_jobs) != 49 * 17:
    raise RuntimeError(f'Expected 833 eta-function files, found {len(eta_func_jobs)}.')
eta_func_jobs = list(eta_func_jobs.values())
print(f'Selected {len(eta_func_jobs)} unique points on the 49 x 17 grid.')

# %%
def process_file(job):
    filename, result_path, binned_path = job
    file_stem = filename.stem
    output_paths = [result_path, binned_path]
    if all(path.exists() for path in output_paths) and all(path.stat().st_mtime >= filename.stat().st_mtime for path in output_paths):
        print('File has already been processed.')
        return 0
    # 正则表达式匹配 mDM 和 sigma 的值
    pattern = r"mDM=([0-9.eE+-]+)_GeV_sigma=([0-9.eE+-]+)_cm2"
    # 使用 re.search() 匹配并提取
    match = re.search(pattern, file_stem)
    mDM_in_GeV = float(match.group(1))  # 第一个括号组匹配 mDM 的值
    sigma_e_in_cm2 = float(match.group(2))  # 第二个括号组匹配 sigma 的值
    mDM = mDM_in_GeV * nu.GeV
    sigma_e = sigma_e_in_cm2 * nu.cm * nu.cm
    eta_func = np.loadtxt(filename)
    eta_func_interp = interp1d(eta_func[:,0], eta_func[:,1])
    def EtaFunction(vMin):
        if vMin < eta_func[0,0] or vMin > eta_func[-1,0]:
            return 0
        else:
            return eta_func_interp(vMin).item()
    # Energy spectrum per mass:
    def dRdEe_halo(Ee, sigma_e, mDM, target):
        if target!="hgte" and target!="cdte":
            raise ValueError("target not recognized for JWST")
        elif target == "hgte":
            integral  = 0.0
            prefactor = rho_DM * frac_DM / mDM / M_cell * nu.aEM * sigma_e * nu.mElectron**2 / nu.Reduced_Mass(nu.mElectron, mDM)**2
            for qi in q_grid:
                vMin = v_min(qi, Ee, mDM)
                ff_qiE = ff_hgte((qi, Ee))
                integral += prefactor * dq / qi**2 * EtaFunction(vMin) * F_DM(qi)**2 * ff_qiE
        elif target == "cdte":
            integral  = 0.0
            prefactor = rho_DM * frac_DM / mDM / M_cell * nu.aEM * sigma_e * nu.mElectron**2 / nu.Reduced_Mass(nu.mElectron, mDM)**2
            for qi in q_grid:
                vMin = v_min(qi, Ee, mDM)
                ff_qiE = ff_cdte((qi, Ee))
                integral += prefactor * dq / qi**2 * EtaFunction(vMin) * F_DM(qi)**2 * ff_qiE
        return integral
    # Electron spectrum per mass:
    def R_Q_halo(Q, sigma_e, mDM, target):
        R_Q = 0
        for Ei in E_grid:
            cy = charge_yield(Ei, Q)
            R_Q += dE * cy * dRdEe_halo(Ei, sigma_e, mDM, target)
        return R_Q
    nq = np.zeros(30)
    total_charge = 0
    for q in range(30):
        nq_hgte = exposure * R_Q_halo(q+1, sigma_e, mDM, "hgte")
        nq_cdte = exposure * R_Q_halo(q+1, sigma_e, mDM, "cdte")
        nq[q] = np.min((nq_hgte, nq_cdte))
        total_charge += (q+1) * nq[q]
    result = [mDM_in_GeV, sigma_e_in_cm2, total_charge]
    np.savetxt(result_path, result)
    np.savetxt(binned_path, nq)
    print(file_stem + '   completed')

    return 0

# %%
# 使用 ProcessPoolExecutor 并行处理文件，限制最大进程数为 20
with concurrent.futures.ProcessPoolExecutor(max_workers=22) as executor:
    # 获取文件夹中所有的文件路径
    # 提交文件处理任务到进程池
    futures = {executor.submit(process_file, job): job[0] for job in eta_func_jobs}
    
    # 逐个处理完成的任务
    for future in concurrent.futures.as_completed(futures):
        file = futures[future]
        try:
            result = future.result()  # 获取任务的返回值
            print(f"Finished processing {result}")
        except Exception as exc:
            print(f"Error processing {file}: {exc}")
# Out:
# eta_func_mDM=0.001_GeV_sigma=5.11042e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=3.83227e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=3.83227e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=6.81485e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=4.83925e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=2.13359e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=5.49433e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=4.81761e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=2.77797e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=2.03157e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.08351e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=2.56941e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=6.89939e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=2.26923e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=9.27794e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=3.20056e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=6.95747e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=6.80532e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=2.70914e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=4.26802e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=2.26923e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.92679e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=6.81753e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=2.15505e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=2.70914e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=6.81753e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=2.40009e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=1.56217e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=3.87981e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=7.17593e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=2.90945e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=2.20015e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=5.21737e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=4.03532e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=2.56941e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=4.26802e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=6.89939e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.08351e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=1.61669e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=1.94182e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=1.23723e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=6.80532e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=1.64988e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.08351e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=1.26359e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=3.62892e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=1.61669e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=4.45746e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=6.45324e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=2.72131e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=1.21187e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=1.09196e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=1.21018e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=7.1057e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=5.21737e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=8.99727e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=4.56914e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=1.6361e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=8.1252e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=4.60478e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=6.81753e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=6.09304e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=9.77045e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=6.42439e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=8.18858e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=1.40957e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=2.8738e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=3.79412e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=2.15505e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=5.94412e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=9.56926e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=1.14244e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=2.72131e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=9.27794e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=9.09132e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=6.747e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=2.04069e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=2.87493e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=6.14057e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=1.59997e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=1.45616e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=4.94e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=9.77045e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=6.95747e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=1.6361e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=5.38119e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=1.8797e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=5.38119e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=1.61379e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=7.1057e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=7.17593e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=1.61669e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=4.38037e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=8.99727e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=2.15589e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=6.747e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=2.93394e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=1.73746e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=9.08776e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=7.92661e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=2.40009e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=5.11042e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=1.26359e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=7.3268e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=1.52346e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=1.05703e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=1.05703e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=1.45616e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=1.34967e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=7.78952e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=1.68503e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=3.70448e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=3.4531e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=1.68503e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=2.8738e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=2.08318e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=1.21187e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=3.4531e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=2.15203e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=1.61379e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=1.61606e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=1.8797e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=6.5876e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=1.01211e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=8.7847e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=1.56217e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=9.09132e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=1.64988e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=7.3268e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=5.17381e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=8.56706e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=8.7847e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=5.32852e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=4.83925e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=6.14057e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=1.61669e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=3.6127e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=2.13359e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.08351e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=5.11243e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=9.09132e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=1.73746e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=3.82691e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=2.15203e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=1.30291e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=8.18858e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=6.81485e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=4.45746e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=3.79412e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=4.03532e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00562341_GeV_sigma=1.21235e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=9.77045e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=3.16228_GeV_sigma=2.58946e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=2.46326e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=2.24702e-26_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=1.14757e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=9.4756e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=6.42439e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=2.40009e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=1.73746e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=5.62341_GeV_sigma=1.14244e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=1.14757e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.001_GeV_sigma=2.15505e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=3.28481e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=2.31694e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=1.56217e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=6.89939e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0316228_GeV_sigma=2.20015e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=4.56914e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=3.28481e-21_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=1.84719e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.44489e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.316228_GeV_sigma=1.92679e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0562341_GeV_sigma=5.94412e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=8.99727e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00177828_GeV_sigma=8.60554e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1_GeV_sigma=1.30291e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=1.17146e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.01_GeV_sigma=5.6915e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=3.82691e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.177828_GeV_sigma=2.90945e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.00316228_GeV_sigma=1.26359e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=1.27608e-24_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.562341_GeV_sigma=2.86978e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=3.28481e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=2.84519e-22_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.1_GeV_sigma=6.747e-25_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=0.0177828_GeV_sigma=1.70168e-23_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=10_GeV_sigma=4.94e-20_cm2_vMin=0_kps   completed
# Finished processing 0
# eta_func_mDM=1.77828_GeV_sigma=1